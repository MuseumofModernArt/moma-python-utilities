# %%
import subprocess
import re

from typing import List

create_re = re.compile(r'CREATE TABLE public\.([a-z_]+) \(\n[ ]{4}(.+\n)+')
fk_re = re.compile(r'(FOREIGN KEY (\([a-z_]+\)) REFERENCES public.[a-z_]+\([a-z_]+\))')

DTYPE_CONVERSION = [
    ('varchar', 'STRING'),
    ('character', 'STRING'),
    ('char', 'STRING'),
    ('text', 'STRING'),
    ('uuid', 'STRING(72)'),
    ('bigint', 'INT64'),
    ('int', 'INT64'),
    ('boolean', 'BOOL'),
    ('datetime', 'TIMESTAMP'),
    ('timestamp', 'TIMESTAMP'),
    ('time', 'TIMESTAMP'),
    ('date', 'TIMESTAMP'),
    ('jsonb', 'JSON')
]

def get_table_create_statement(table_name: str) -> str:
    # This string uses backticks just like your terminal command
    # It fetches the URL and passes it to pg_dump in one go
    cmd = f"pg_dump -s -t {table_name} `heroku config:get DATABASE_URL -a sfdb-staging`"
    
    try:
        # shell=True is required to interpret the backticks
        result = subprocess.run(
            cmd, 
            shell=True, 
            capture_output=True, 
            text=True, 
            check=True
        )
        return result.stdout
    except subprocess.CalledProcessError as e:
        print(f"Error: {e.stderr}")
        return None

def generate_table_names(table: str) -> List[str]:
    return([
        f'`moma-dw.moma_apps.{table}`',
        f'`moma-membership.moma_import.{table}`',
        f'`moma-dw.moma_apps_staging.{table}`',
        f'`moma-apps-staging.moma_import.{table}`',
    ])

# %%
full_statement = get_table_create_statement('gift_membership_batch_sales')

print(full_statement)
# Out:
# --
# -- PostgreSQL database dump
# --
#
# \restrict 7gySYyWXPrBQ9wRjicyM0qPkwFZdkNKirHduO5z76mF4RVhzNnoHFa1JPvz7Vge
#
# -- Dumped from database version 16.9 (Ubuntu 16.9-1.pgdg20.04+1)
# -- Dumped by pg_dump version 18.0 (Postgres.app)
#
# SET statement_timeout = 0;
# SET lock_timeout = 0;
# SET idle_in_transaction_session_timeout = 0;
# SET transaction_timeout = 0;
# SET client_encoding = 'UTF8';
# SET standard_conforming_strings = on;
# SELECT pg_catalog.set_config('search_path', '', false);
# SET check_function_bodies = false;
# SET xmloption = content;
# SET client_min_messages = warning;
# SET row_security = off;
#
# SET default_tablespace = '';
#
# SET default_table_access_method = heap;
#
# --
# -- Name: gift_membership_batch_sales; Type: TABLE; Schema: public; Owner: udt1bh1siv5puv
# --
#
# CREATE TABLE public.gift_membership_batch_sales (
#     id bigint NOT NULL,
#     gift_membership_batch_id bigint NOT NULL,
#     line_item_type character varying NOT NULL,
#     line_item_id bigint NOT NULL,
#     created_at timestamp(6) without time zone NOT NULL,
#     updated_at timestamp(6) without time zone NOT NULL,
#     gift_giver_first_name character varying,
#     gift_giver_last_name character varying,
#     gift_giver_email character varying
# );
#
#
# ALTER TABLE public.gift_membership_batch_sales OWNER TO udt1bh1siv5puv;
#
# --
# -- Name: gift_membership_batch_sales_id_seq; Type: SEQUENCE; Schema: public; Owner: udt1bh1siv5puv
# --
#
# CREATE SEQUENCE public.gift_membership_batch_sales_id_seq
#     START WITH 1
#     INCREMENT BY 1
#     NO MINVALUE
#     NO MAXVALUE
#     CACHE 1;
#
#
# ALTER SEQUENCE public.gift_membership_batch_sales_id_seq OWNER TO udt1bh1siv5puv;
#
# --
# -- Name: gift_membership_batch_sales_id_seq; Type: SEQUENCE OWNED BY; Schema: public; Owner: udt1bh1siv5puv
# --
#
# ALTER SEQUENCE public.gift_membership_batch_sales_id_seq OWNED BY public.gift_membership_batch_sales.id;
#
#
# --
# -- Name: gift_membership_batch_sales id; Type: DEFAULT; Schema: public; Owner: udt1bh1siv5puv
# --
#
# ALTER TABLE ONLY public.gift_membership_batch_sales ALTER COLUMN id SET DEFAULT nextval('public.gift_membership_batch_sales_id_seq'::regclass);
#
#
# --
# -- Name: gift_membership_batch_sales gift_membership_batch_sales_pkey; Type: CONSTRAINT; Schema: public; Owner: udt1bh1siv5puv
# --
#
# ALTER TABLE ONLY public.gift_membership_batch_sales
#     ADD CONSTRAINT gift_membership_batch_sales_pkey PRIMARY KEY (id);
#
#
# --
# -- Name: idx_on_gift_giver_first_name_gift_giver_last_name_g_2b983ce60a; Type: INDEX; Schema: public; Owner: udt1bh1siv5puv
# --
#
# CREATE INDEX idx_on_gift_giver_first_name_gift_giver_last_name_g_2b983ce60a ON public.gift_membership_batch_sales USING btree (gift_giver_first_name, gift_giver_last_name, gift_giver_email);
#
#
# --
# -- Name: index_gift_membership_batch_sales_on_gift_membership_batch_id; Type: INDEX; Schema: public; Owner: udt1bh1siv5puv
# --
#
# CREATE INDEX index_gift_membership_batch_sales_on_gift_membership_batch_id ON public.gift_membership_batch_sales USING btree (gift_membership_batch_id);
#
#
# --
# -- Name: index_gift_membership_batch_sales_on_line_item; Type: INDEX; Schema: public; Owner: udt1bh1siv5puv
# --
#
# CREATE INDEX index_gift_membership_batch_sales_on_line_item ON public.gift_membership_batch_sales USING btree (line_item_type, line_item_id);
#
#
# --
# -- Name: index_unique_line_items_in_batches; Type: INDEX; Schema: public; Owner: udt1bh1siv5puv
# --
#
# CREATE UNIQUE INDEX index_unique_line_items_in_batches ON public.gift_membership_batch_sales USING btree (line_item_type, line_item_id);
#
#
# --
# -- Name: gift_membership_batch_sales fk_rails_4513a182ef; Type: FK CONSTRAINT; Schema: public; Owner: udt1bh1siv5puv
# --
#
# ALTER TABLE ONLY public.gift_membership_batch_sales
#     ADD CONSTRAINT fk_rails_4513a182ef FOREIGN KEY (gift_membership_batch_id) REFERENCES public.gift_membership_batches(id);
#
#
# --
# -- Name: TABLE gift_membership_batch_sales; Type: ACL; Schema: public; Owner: udt1bh1siv5puv
# --
#
# GRANT SELECT ON TABLE public.gift_membership_batch_sales TO "RikTest";
# GRANT SELECT,INSERT,DELETE,TRUNCATE,UPDATE ON TABLE public.gift_membership_batch_sales TO ffscripts;
# GRANT SELECT,INSERT,REFERENCES,DELETE,TRIGGER,TRUNCATE,UPDATE ON TABLE public.gift_membership_batch_sales TO internal_utility_u3v0k5sf64tkvn;
# GRANT SELECT,INSERT,DELETE,TRUNCATE,UPDATE ON TABLE public.gift_membership_batch_sales TO rik_fix_error_log_table;
#
#
# --
# -- Name: SEQUENCE gift_membership_batch_sales_id_seq; Type: ACL; Schema: public; Owner: udt1bh1siv5puv
# --
#
# GRANT SELECT ON SEQUENCE public.gift_membership_batch_sales_id_seq TO "RikTest";
# GRANT SELECT,USAGE ON SEQUENCE public.gift_membership_batch_sales_id_seq TO ffscripts;
# GRANT SELECT,USAGE ON SEQUENCE public.gift_membership_batch_sales_id_seq TO rik_fix_error_log_table;
#
#
# --
# -- PostgreSQL database dump complete
# --
#
# \unrestrict 7gySYyWXPrBQ9wRjicyM0qPkwFZdkNKirHduO5z76mF4RVhzNnoHFa1JPvz7Vge

# %%
create_statement = re.search(
    create_re,
    full_statement
)[0]

print(create_statement)
# Out:
# CREATE TABLE public.gift_membership_batch_sales (
#     id bigint NOT NULL,
#     gift_membership_batch_id bigint NOT NULL,
#     line_item_type character varying NOT NULL,
#     line_item_id bigint NOT NULL,
#     created_at timestamp(6) without time zone NOT NULL,
#     updated_at timestamp(6) without time zone NOT NULL,
#     gift_giver_first_name character varying,
#     gift_giver_last_name character varying,
#     gift_giver_email character varying
# );

# %%
fk_statement = re.search(
    fk_re,
    full_statement
)

fk_statement[0]
# Out:
# 'FOREIGN KEY (gift_membership_batch_id) REFERENCES public.gift_membership_batches(id)'
